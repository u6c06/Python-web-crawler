# %% [markdown]
# ```
# conda activate ai37
#
# 在prompt打activate ai37
# 然後pip install gspread oauth2client
#
# ModuleNotFoundError: No module named 'gspread'
# 可以試試看直接在 jupyter開一欄
# 輸入
# !pip install gspread oauth2client
# 按ctrl+enter 執行看看
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#老師
import gspread
from oauth2client.service_account import ServiceAccountCredentials as sac

auth_json = 'simon-0513-f72abfd80586.json'
gs_scopes = ['https://spreadsheets.google.com/feeds']
cr = sac.from_json_keyfile_name(auth_json, gs_scopes)
gc = gspread.authorize(cr)
spreadsheet_key = '16PcqdVU5i2pzGRoHh5i_brqtkdMRhhtoOClio2I98HY'
sheet = gc.open_by_key(spreadsheet_key)

# 開啟工作簿
wks = sheet.sheet1
# 清除所有內容
wks.clear() 
# 新增列
listtitle=['座號', '姓名', '國文', '英文', '數學']
wks.append_row(listtitle)  # 標題
listdatas=[[1, '葉大雄', 65, 62, 40],
           [2, '陳靜香', 85, 90, 87],
           [3, '王聰明', 92, 90, 95]]
for listdata in listdatas:
    wks.append_row(listdata)  # 資料內容

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials as sac
auth_json="yh0512-ab1fb430fd6e.json"
gs_scopes=["https://spreadsheets.google.com/feeds"]
cr=sac.from_json_keyfile_name(auth_json,gs_scopes)
gc=gspread.authorize(cr)

spreadsheet_key="11EHrhGeVZSsu6SWraiJc7nBb__nhStbsMSbj_6DG8Zk"

sheet=gc.open_by_key(spreadsheet_key)

# 開啟工作簿
wks = sheet.sheet1
# 清除所有內容
wks.clear() 
# 新增列
listtitle=['座號', '姓名', '國文', '英文', '數學']
wks.append_row(listtitle)  # 標題
listdatas=[[1, '葉大雄', 65, 62, 40],
           [2, '陳靜香', 85, 90, 87],
           [3, '王聰明', 92, 90, 95]]
for listdata in listdatas:
    wks.append_row(listdata)  # 資料內容

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %%
import requests
url="http://www.ehappy.tw/demo.htm"
html=requests.get(url)
print(html.status_code)
if html.status_code==requests.codes.ok:
    print(html.text)
# Out:
# 200
# <!doctype html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <title>Hello</title>
#   </head>
#   <body>
#     <p>Hello World!</p>
#   </body>
# </html>

# %% [markdown]
# ![image.png](attachment:image.png)
#     ?為接參數

# %%
import requests
payload={'key1':'value1','key2':'value2'}
html=requests.get("http://httpbin.org/get",params=payload)
if html.status_code==requests.codes.ok:
    print(html.text)
# Out:
# {
#   "args": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-627e010e-43f634b12e8568d95fe8954e"
#   },
#   "origin": "125.228.13.251",
#   "url": "http://httpbin.org/get?key1=value1&key2=value2"
# }

# %% [markdown]
# ![image.png](attachment:image.png)
#     http://httpbin.org/forms/post
# ![image-2.png](attachment:image-2.png)
#     post用於網頁表單

# %%
import requests
payload={'key1':'value1','key2':'value2'}
r=requests.post("http://httpbin.org/post",data=payload)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-627e027b-4f34839b3db6f8cc3167dcef"
#   },
#   "json": null,
#   "origin": "125.228.13.251",
#   "url": "http://httpbin.org/post"
# }

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
url="https://irs.thsrc.com.tw/IMINT"
headers={'user-agent':'Mazilla/5.0'}
html=requests.get(url,headers=headers)
print(html.status_code)
# Out:
# 200

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
url="https://www.ptt.cc/bbs/Gossiping/index.html"
cookies={'over18':'1'}
r=requests.get(url,cookies=cookies)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	<script async src='/cdn-cgi/challenge-platform/h/b/scripts/invisible.js?ts=1652425200'></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
#     pip install  beautifulsoup4
# ![image-2.png](attachment:image-2.png)
#     http://ehappy.tw/bsdemo1.htm
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
from bs4 import BeautifulSoup

url="http://ehappy.tw/bsdemo1.htm"
html=requests.get(url)
html.encoding='UTF-8'
#print(html.text)
sp=BeautifulSoup(html.text,'lxml')
print(sp.title)
print(sp.title.text)
print(sp.h1)
print(sp.h1.text)
print(sp.p)
print(sp.p.text)
print(sp.img)
# Out:
# <title>我是網頁標題</title>
# 我是網頁標題
# <h1 class="large">我是標題</h1>
# 我是標題
# <p>我是段落</p>
# 我是段落
# <img alt="我是圖片" src="https://www.w3.org/html/logo/downloads/HTML5_Logo_256.png"/>

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)

# %%
from bs4 import BeautifulSoup
html='''
<html>
    <head>
        <meta charset="UTF-8">
        <title>
        我是網頁標題
        </title>
    </head>
    <body>
        <p id="p1">我是段落一</p>
        <p id="p2" class='red'>我是段落二</p>
    </body>
</html>
'''
sp=BeautifulSoup(html,'lxml')
print(sp.find('p'))
print(sp.find_all('p'))
print(sp.find('p',id='p2',class_='red'))
print(sp.find('p',{'id':'p2','class':'red'})) #python style
# Out:
# <p id="p1">我是段落一</p>
# [<p id="p1">我是段落一</p>, <p class="red" id="p2">我是段落二</p>]
# <p class="red" id="p2">我是段落二</p>
# <p class="red" id="p2">我是段落二</p>

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from bs4 import BeautifulSoup
html='''
<html>
    <head>
        <meta charset="UTF-8">
        <title>
        我是網頁標題
        </title>
    </head>
    <body>
        <p id="p1">我是段落一</p>
        <p id="p2" class='red'>我是段落二</p>
    </body>
</html>
'''
sp=BeautifulSoup(html,'lxml')
print(sp.select('title')) #回傳為串列
print(sp.select('p'))
print(sp.select('#p1')) # #為用id找
print(sp.select('.red'))# .為用class找
# Out:
# [<title>
#         我是網頁標題
#         </title>]
# [<p id="p1">我是段落一</p>, <p class="red" id="p2">我是段落二</p>]
# [<p id="p1">我是段落一</p>]
# [<p class="red" id="p2">我是段落二</p>]

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from bs4 import BeautifulSoup
html='''
<html>
    <head>
        <meta charset="UTF-8">
        <title>
        我是網頁標題
        </title>
    </head>
    <body>
        <img src="http://www.ehappy.tw/python.png">
        <a href="http://www.e-happy.com.tw">超連結</a>
    </body>
</html>
'''
sp=BeautifulSoup(html,'lxml')
print(sp.select('img')) 
print(sp.select('img')[0].get('src'))#函數
print(sp.select('img')[0]['src'])    #串列 #python style
print(sp.select('a')[0]['href'])
# Out:
# [<img src="http://www.ehappy.tw/python.png"/>]
# http://www.ehappy.tw/python.png
# http://www.ehappy.tw/python.png
# http://www.e-happy.com.tw

# %% [markdown]
# ![image.png](attachment:image.png)
#     https://www.taiwanlottery.com.tw/

# %%
import requests
from bs4 import BeautifulSoup

url="https://www.taiwanlottery.com.tw/"
r=requests.get(url)
sp=BeautifulSoup(r.text,'lxml')

data=sp.find('div',class_="contents_box02")
print(data)
# Out:
# <div class="contents_box02">
# <div id="contents_logo_02"></div><div class="contents_mine_tx02"><span class="font_black15">111/5/12 第111000038期 </span><span class="font_red14"><a href="Result_all.aspx#01">開獎結果</a></span></div><div class="contents_mine_tx04">開出順序<br/>大小順序<br/>第二區</div><div class="ball_tx ball_green">01 </div><div class="ball_tx ball_green">34 </div><div class="ball_tx ball_green">13 </div><div class="ball_tx ball_green">26 </div><div class="ball_tx ball_green">21 </div><div class="ball_tx ball_green">02 </div><div class="ball_tx ball_green">01 </div><div class="ball_tx ball_green">02 </div><div class="ball_tx ball_green">13 </div><div class="ball_tx ball_green">21 </div><div class="ball_tx ball_green">26 </div><div class="ball_tx ball_green">34 </div><div class="ball_red">06 </div>
# </div>

# %%
title=data.find('span',class_='font_black15').text
print(title)
nums=data.find_all('div',class_="ball_tx ball_green")
print("開出順序:",end=" ")
for i in range(0,6):
    print(nums[i].text,end=" ")
print()
print("大小順序:",end=" ")
for j in range(6,12):
    print(nums[j].text,end=" ")
print()
num=data.find('div',class_="ball_red").text
print("第二區:",num,end=" ")
# Out:
# 111/5/12 第111000038期
# 開出順序: 01  34  13  26  21  02
# 大小順序: 01  02  13  21  26  34
# 第二區: 06

# %% [markdown]
#     HW: 台灣彩券 https://www.taiwanlottery.com.tw/

# %%
#BINGO BINGO
import requests
from bs4 import BeautifulSoup

url="https://www.taiwanlottery.com.tw/"
r=requests.get(url)
sp=BeautifulSoup(r.text,'lxml')

data=sp.find('div',class_="contents_box01")
print(data)
print()
title=data.find('span',class_='font_black15').text
print(title)
nums=data.find_all('div',class_="ball_tx ball_yellow")
print("開出順序:",end=" ")
for i in range(0,20):
    print(nums[i].text,end=" ")
# Out:
# <div class="contents_box01">
# ...

# %%
#雙贏彩
import requests
from bs4 import BeautifulSoup

url="https://www.taiwanlottery.com.tw/"
r=requests.get(url)
sp=BeautifulSoup(r.text,'lxml')

data=sp.find('div',class_="contents_box06")
print(data)
print()
title=data.find('span',class_='font_black15').text
print(title)
nums=data.find_all('div',class_="ball_tx ball_blue")
print("開出順序:",end=" ")
for i in range(0,12):
    print(nums[i].text,end=" ")
print()
print("大小順序:",end=" ")
for j in range(12,24):
    print(nums[j].text,end=" ")
# Out:
# <div class="contents_box06">
# ...

# %%
#威力彩
import requests
from bs4 import BeautifulSoup

url="https://www.taiwanlottery.com.tw/"
r=requests.get(url)
sp=BeautifulSoup(r.text,'lxml')

data=sp.find('div',class_="contents_box02")
print(data)
print()
title=data.find('span',class_='font_black15').text
print(title)
nums=data.find_all('div',class_="ball_tx ball_green")
print("開出順序:",end=" ")
for i in range(0,6):
    print(nums[i].text,end=" ")
print()
print("大小順序:",end=" ")
for j in range(6,12):
    print(nums[j].text,end=" ")
print()
num=data.find('div',class_="ball_red").text
print("第二區:",num,end=" ")
# Out:
# <div class="contents_box02">
# <div id="contents_logo_02"></div><div class="contents_mine_tx02"><span class="font_black15">111/5/12 第111000038期 </span><span class="font_red14"><a href="Result_all.aspx#01">開獎結果</a></span></div><div class="contents_mine_tx04">開出順序<br/>大小順序<br/>第二區</div><div class="ball_tx ball_green">01 </div><div class="ball_tx ball_green">34 </div><div class="ball_tx ball_green">13 </div><div class="ball_tx ball_green">26 </div><div class="ball_tx ball_green">21 </div><div class="ball_tx ball_green">02 </div><div class="ball_tx ball_green">01 </div><div class="ball_tx ball_green">02 </div><div class="ball_tx ball_green">13 </div><div class="ball_tx ball_green">21 </div><div class="ball_tx ball_green">26 </div><div class="ball_tx ball_green">34 </div><div class="ball_red">06 </div>
# </div>
#
# 111/5/12 第111000038期
# 開出順序: 01  34  13  26  21  02
# 大小順序: 01  02  13  21  26  34
# 第二區: 06

# %%
#38樂合彩
import requests
from bs4 import BeautifulSoup

url="https://www.taiwanlottery.com.tw/"
r=requests.get(url)
sp=BeautifulSoup(r.text,'lxml')

data=sp.find_all('div',class_="contents_box02")
print(data[1])
print()
title=data[1].find('span',class_='font_black15').text
print(title)
nums=data[1].find_all('div',class_="ball_tx ball_green")
print("開出順序:",end=" ")
for i in range(0,6):
    print(nums[i].text,end=" ")
print()
print("大小順序:",end=" ")
for j in range(6,12):
    print(nums[j].text,end=" ")
# Out:
# <div class="contents_box02">
# <div id="contents_logo_03"></div><div class="contents_mine_tx02"><span class="font_black15">111/5/12 第111000038期 </span><span class="font_red14"><a href="Result_all.aspx#07">開獎結果</a></span></div><div class="contents_mine_tx04">開出順序<br/>大小順序</div><div class="ball_tx ball_green">01 </div><div class="ball_tx ball_green">34 </div><div class="ball_tx ball_green">13 </div><div class="ball_tx ball_green">26 </div><div class="ball_tx ball_green">21 </div><div class="ball_tx ball_green">02 </div><div class="ball_tx ball_green">01 </div><div class="ball_tx ball_green">02 </div><div class="ball_tx ball_green">13 </div><div class="ball_tx ball_green">21 </div><div class="ball_tx ball_green">26 </div><div class="ball_tx ball_green">34 </div>
# </div>
#
# 111/5/12 第111000038期
# 開出順序: 01  34  13  26  21  02
# 大小順序: 01  02  13  21  26  34

# %%
#大樂透
import requests
from bs4 import BeautifulSoup

url="https://www.taiwanlottery.com.tw/"
r=requests.get(url)
sp=BeautifulSoup(r.text,'lxml')

data=sp.find_all('div',class_="contents_box02")
print(data[2])
print()
title=data[2].find('span',class_='font_black15').text
print(title)
nums=data[2].find_all('div',class_="ball_tx ball_yellow")
print("開出順序:",end=" ")
for i in range(0,6):
    print(nums[i].text,end=" ")
print()
print("大小順序:",end=" ")
for j in range(6,12):
    print(nums[j].text,end=" ")
print()
num=data[2].find('div',class_="ball_red").text
print("特別號:",num,end=" ")
# Out:
# <div class="contents_box02">
# <div id="contents_logo_04"></div><div class="contents_mine_tx02"><span class="font_black15">111/5/13 第111000048期 </span><span class="font_red14"><a href="Result_all.aspx#02">開獎結果</a></span></div><div class="contents_mine_tx04">開出順序<br/>大小順序<br/>特別號</div><div class="ball_tx ball_yellow">36 </div><div class="ball_tx ball_yellow">24 </div><div class="ball_tx ball_yellow">37 </div><div class="ball_tx ball_yellow">10 </div><div class="ball_tx ball_yellow">48 </div><div class="ball_tx ball_yellow">27 </div><div class="ball_tx ball_yellow">10 </div><div class="ball_tx ball_yellow">24 </div><div class="ball_tx ball_yellow">27 </div><div class="ball_tx ball_yellow">36 </div><div class="ball_tx ball_yellow">37 </div><div class="ball_tx ball_yellow">48 </div><div class="ball_red">29 </div>
# </div>
#
# 111/5/13 第111000048期
# 開出順序: 36  24  37  10  48  27
# 大小順序: 10  24  27  36  37  48
# 特別號: 29

# %%
#49樂合彩
import requests
from bs4 import BeautifulSoup

url="https://www.taiwanlottery.com.tw/"
r=requests.get(url)
sp=BeautifulSoup(r.text,'lxml')

data=sp.find_all('div',class_="contents_box02")
print(data[3])
print()
title=data[3].find('span',class_='font_black15').text
print(title)
nums=data[3].find_all('div',class_="ball_tx ball_yellow")
print("開出順序:",end=" ")
for i in range(0,6):
    print(nums[i].text,end=" ")
print()
print("大小順序:",end=" ")
for j in range(6,12):
    print(nums[j].text,end=" ")
# Out:
# <div class="contents_box02">
# <div id="contents_logo_05"></div><div class="contents_mine_tx02"><span class="font_black15">111/5/13 第111000048期 </span><span class="font_red14"><a href="Result_all.aspx#08">開獎結果</a></span></div><div class="contents_mine_tx04">開出順序<br/>大小順序</div><div class="ball_tx ball_yellow">36 </div><div class="ball_tx ball_yellow">24 </div><div class="ball_tx ball_yellow">37 </div><div class="ball_tx ball_yellow">10 </div><div class="ball_tx ball_yellow">48 </div><div class="ball_tx ball_yellow">27 </div><div class="ball_tx ball_yellow">10 </div><div class="ball_tx ball_yellow">24 </div><div class="ball_tx ball_yellow">27 </div><div class="ball_tx ball_yellow">36 </div><div class="ball_tx ball_yellow">37 </div><div class="ball_tx ball_yellow">48 </div>
# </div>
#
# 111/5/13 第111000048期
# 開出順序: 36  24  37  10  48  27
# 大小順序: 10  24  27  36  37  48

# %%
#今彩539
import requests
from bs4 import BeautifulSoup

url="https://www.taiwanlottery.com.tw/"
r=requests.get(url)
sp=BeautifulSoup(r.text,'lxml')

data=sp.find('div',class_="contents_box03")
print(data)
print()
title=data.find('span',class_='font_black15').text
print(title)
nums=data.find_all('div',class_="ball_tx ball_lemon")
print("開出順序:",end=" ")
for i in range(0,5):
    print(nums[i].text,end=" ")
print()
print("大小順序:",end=" ")
for j in range(5,10):
    print(nums[j].text,end=" ")
# Out:
# <div class="contents_box03">
# <div id="contents_logo_06"></div><div class="contents_mine_tx02"><span class="font_black15">111/5/14 第111000115期 </span><span class="font_red14"><a href="Result_all.aspx#03">開獎結果</a></span></div><div class="contents_mine_tx04">開出順序<br/>大小順序</div><div class="ball_tx ball_lemon">01 </div><div class="ball_tx ball_lemon">31 </div><div class="ball_tx ball_lemon">22 </div><div class="ball_tx ball_lemon">19 </div><div class="ball_tx ball_lemon">12 </div><div class="ball_tx"></div><div class="ball_tx ball_lemon">01 </div><div class="ball_tx ball_lemon">12 </div><div class="ball_tx ball_lemon">19 </div><div class="ball_tx ball_lemon">22 </div><div class="ball_tx ball_lemon">31 </div>
# </div>
#
# 111/5/14 第111000115期
# 開出順序: 01  31  22  19  12
# 大小順序: 01  12  19  22  31

# %%
#39樂合彩
import requests
from bs4 import BeautifulSoup

url="https://www.taiwanlottery.com.tw/"
r=requests.get(url)
sp=BeautifulSoup(r.text,'lxml')

data=sp.find_all('div',class_="contents_box03")
print(data[1])
print()
title=data[1].find('span',class_='font_black15').text
print(title)
nums=data[1].find_all('div',class_="ball_tx ball_lemon")
print("開出順序:",end=" ")
for i in range(0,5):
    print(nums[i].text,end=" ")
print()
print("大小順序:",end=" ")
for j in range(5,10):
    print(nums[j].text,end=" ")
# Out:
# <div class="contents_box03">
# <div id="contents_logo_07"></div><div class="contents_mine_tx02"><span class="font_black15">111/5/14 第111000115期 </span><span class="font_red14"><a href="Result_all.aspx#09">開獎結果</a></span></div><div class="contents_mine_tx04">開出順序<br/>大小順序</div><div class="ball_tx ball_lemon">01 </div><div class="ball_tx ball_lemon">31 </div><div class="ball_tx ball_lemon">22 </div><div class="ball_tx ball_lemon">19 </div><div class="ball_tx ball_lemon">12 </div><div class="ball_tx"></div><div class="ball_tx ball_lemon">01 </div><div class="ball_tx ball_lemon">12 </div><div class="ball_tx ball_lemon">19 </div><div class="ball_tx ball_lemon">22 </div><div class="ball_tx ball_lemon">31 </div>
# </div>
#
# 111/5/14 第111000115期
# 開出順序: 01  31  22  19  12
# 大小順序: 01  12  19  22  31

# %%
#3星彩
import requests
from bs4 import BeautifulSoup

url="https://www.taiwanlottery.com.tw/"
r=requests.get(url)
sp=BeautifulSoup(r.text,'lxml')

data=sp.find('div',class_="contents_box04")
print(data)
print()
title=data.find('span',class_='font_black15').text
print(title)
nums=data.find_all('div',class_="ball_tx ball_purple")
print("中獎號碼:",end=" ")
for i in range(0,3):
    print(nums[i].text,end=" ")
# Out:
# <div class="contents_box04">
# <div id="contents_logo_08"></div><div class="contents_mine_tx02"><span class="font_black15">111/5/14 第111000115期 </span><span class="font_red14"><a href="Result_all.aspx#05">開獎結果</a></span></div><div class="contents_mine_tx04">中獎號碼</div><div class="ball_tx ball_purple">9</div><div class="ball_tx ball_purple">1</div><div class="ball_tx ball_purple">9</div>
# </div>
#
# 111/5/14 第111000115期
# 中獎號碼: 9 1 9

# %%
#4星彩
import requests
from bs4 import BeautifulSoup

url="https://www.taiwanlottery.com.tw/"
r=requests.get(url)
sp=BeautifulSoup(r.text,'lxml')

data=sp.find_all('div',class_="contents_box04")
print(data[1])
print()
title=data[1].find('span',class_='font_black15').text
print(title)
nums=data[1].find_all('div',class_="ball_tx ball_purple")
print("中獎號碼:",end=" ")
for i in range(0,4):
    print(nums[i].text,end=" ")
# Out:
# <div class="contents_box04">
# <div id="contents_logo_09"></div><div class="contents_mine_tx02"><span class="font_black15">111/5/14 第111000115期 </span><span class="font_red14"><a href="Result_all.aspx#06">開獎結果</a></span></div><div class="contents_mine_tx04">中獎號碼</div><div class="ball_tx ball_purple">8</div><div class="ball_tx ball_purple">1</div><div class="ball_tx ball_purple">6</div><div class="ball_tx ball_purple">0</div>
# </div>
#
# 111/5/14 第111000115期
# 中獎號碼: 8 1 6 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests

url="https://tw.news.yahoo.com/"
html=requests.get(url)
html.encoding="UTF-8"

htmllist=html.text.splitlines()
n=0
for row in htmllist:
    if "台灣" in row: n+=1
print(n)
# Out:
# 6

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#     天瓏書店 O'Reilly出版社(昆蟲) MANNING出版社-MEAP方式(人物畫)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#     + 是1~無窮多次
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)

# %%
import re
m=re.search(r'[0-9]','abc123xyz')
print(m)
# Out:
# <re.Match object; span=(3, 4), match='1'>

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %%
import re
m=re.match(r'[a-z]+','abc123xyz')
print(m)
print(m.group())
print(m.start())
print(m.end())
print(m.span())
# Out:
# <re.Match object; span=(0, 3), match='abc'>
# abc
# 0
# 3
# (0, 3)

# %%
import re
pat=re.compile('[a-z]+')
m=pat.search('3tem12po')
print(m)
print(m.group())
print(m.start())
print(m.end())
print(m.span())
# Out:
# <re.Match object; span=(1, 4), match='tem'>
# tem
# 1
# 4
# (1, 4)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import re
m=re.findall(r'[a-z]+','abc123xyz')
print(m)
#傳回所有 並表示為串列
# Out:
# ['abc', 'xyz']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import re
pat=re.compile(r'[(][0][\d]{1}[)][\d]{8}') #\d所有數字
